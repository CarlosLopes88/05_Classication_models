# %% [markdown]
# <a href="https://colab.research.google.com/github/CarlosLopes88/05_Classication_models/blob/main/Naive_bayes_PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ETL / EDA

# %% [markdown]
# Processo de importação das bibliotécas:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1º Passo Extração dos dados:

# %%
df = pd.read_csv("sensor.csv")

df.head()
# Out:
#    Unnamed: 0            timestamp  ...  sensor_51  machine_status
# 0           0  2018-04-01 00:00:00  ...   201.3889          NORMAL
# 1           1  2018-04-01 00:01:00  ...   201.3889          NORMAL
# 2           2  2018-04-01 00:02:00  ...   203.7037          NORMAL
# 3           3  2018-04-01 00:03:00  ...   203.1250          NORMAL
# 4           4  2018-04-01 00:04:00  ...   201.3889          NORMAL
#
# [5 rows x 55 columns]

# %% [markdown]
# Analise de colunas e número de linhas da base de dados:

# %%
df.shape
# Out:
# (61646, 55)

# %% [markdown]
# Verificação dos nomes das colunas:

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'timestamp', 'sensor_00', 'sensor_01', 'sensor_02',
#        'sensor_03', 'sensor_04', 'sensor_05', 'sensor_06', 'sensor_07',
#        'sensor_08', 'sensor_09', 'sensor_10', 'sensor_11', 'sensor_12',
#        'sensor_13', 'sensor_14', 'sensor_15', 'sensor_16', 'sensor_17',
#        'sensor_18', 'sensor_19', 'sensor_20', 'sensor_21', 'sensor_22',
#        'sensor_23', 'sensor_24', 'sensor_25', 'sensor_26', 'sensor_27',
#        'sensor_28', 'sensor_29', 'sensor_30', 'sensor_31', 'sensor_32',
#        'sensor_33', 'sensor_34', 'sensor_35', 'sensor_36', 'sensor_37',
#        'sensor_38', 'sensor_39', 'sensor_40', 'sensor_41', 'sensor_42',
#        'sensor_43', 'sensor_44', 'sensor_45', 'sensor_46', 'sensor_47',
#        'sensor_48', 'sensor_49', 'sensor_50', 'sensor_51', 'machine_status'],
#       dtype='object')

# %% [markdown]
# Ánalise do tipo de dados contidos na base de dados:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61646 entries, 0 to 61645
# Data columns (total 55 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      61646 non-null  int64
#  1   timestamp       61646 non-null  object
#  2   sensor_00       57619 non-null  float64
#  3   sensor_01       61582 non-null  float64
#  4   sensor_02       61637 non-null  float64
#  5   sensor_03       61637 non-null  float64
#  6   sensor_04       61637 non-null  float64
#  7   sensor_05       61637 non-null  float64
#  8   sensor_06       61400 non-null  float64
#  9   sensor_07       61442 non-null  float64
#  10  sensor_08       60936 non-null  float64
#  11  sensor_09       61637 non-null  float64
#  12  sensor_10       61637 non-null  float64
#  13  sensor_11       61637 non-null  float64
#  14  sensor_12       61637 non-null  float64
#  15  sensor_13       61637 non-null  float64
#  16  sensor_14       61636 non-null  float64
#  17  sensor_15       0 non-null      float64
#  18  sensor_16       61636 non-null  float64
#  19  sensor_17       61636 non-null  float64
#  20  sensor_18       61636 non-null  float64
#  21  sensor_19       61636 non-null  float64
#  22  sensor_20       61636 non-null  float64
#  23  sensor_21       61636 non-null  float64
#  24  sensor_22       61636 non-null  float64
#  25  sensor_23       61636 non-null  float64
#  26  sensor_24       61636 non-null  float64
#  27  sensor_25       61636 non-null  float64
#  28  sensor_26       61636 non-null  float64
#  29  sensor_27       61636 non-null  float64
#  30  sensor_28       61636 non-null  float64
#  31  sensor_29       61636 non-null  float64
#  32  sensor_30       61391 non-null  float64
#  33  sensor_31       61636 non-null  float64
#  34  sensor_32       61636 non-null  float64
#  35  sensor_33       61636 non-null  float64
#  36  sensor_34       61636 non-null  float64
#  37  sensor_35       61636 non-null  float64
#  38  sensor_36       61636 non-null  float64
#  39  sensor_37       61636 non-null  float64
#  40  sensor_38       61637 non-null  float64
#  41  sensor_39       61637 non-null  float64
#  42  sensor_40       61637 non-null  float64
#  43  sensor_41       61637 non-null  float64
#  44  sensor_42       61637 non-null  float64
#  45  sensor_43       61637 non-null  float64
#  46  sensor_44       61637 non-null  float64
#  47  sensor_45       61637 non-null  float64
#  48  sensor_46       61637 non-null  float64
#  49  sensor_47       61637 non-null  float64
#  50  sensor_48       61637 non-null  float64
#  51  sensor_49       61636 non-null  float64
#  52  sensor_50       61636 non-null  float64
#  53  sensor_51       61636 non-null  float64
#  54  machine_status  61645 non-null  object
# dtypes: float64(52), int64(1), object(2)
# memory usage: 25.9+ MB

# %% [markdown]
# 2º Passo transformação:
#
# Renomear a colunas timestamp para 'data' e ajustas o formato.

# %%
df = df.rename(columns={'timestamp':'data'})

df['data'] = df['data'].str.slice(stop=10)

df['data'] = df['data'].astype('datetime64[D]')

df.head()
# Out:
#    Unnamed: 0       data  sensor_00  ...  sensor_50  sensor_51  machine_status
# 0           0 2018-04-01   2.465394  ...   243.0556   201.3889          NORMAL
# 1           1 2018-04-01   2.465394  ...   243.0556   201.3889          NORMAL
# 2           2 2018-04-01   2.444734  ...   241.3194   203.7037          NORMAL
# 3           3 2018-04-01   2.460474  ...   240.4514   203.1250          NORMAL
# 4           4 2018-04-01   2.445718  ...   242.1875   201.3889          NORMAL
#
# [5 rows x 55 columns]

# %% [markdown]
# Armazenando a base limpa:

# %%
df.to_csv("sensor_limpa.csv", index = False)

# %% [markdown]
# Vericação de dados nulos contidos na base:

# %%
for column in df.columns.values.tolist():
  total = df[column].isna().sum()
  if total > 1:
    print(column, "\t NaN = ",total)
# Out:
# sensor_00 	 NaN =  4027
# sensor_01 	 NaN =  64
# sensor_02 	 NaN =  9
# sensor_03 	 NaN =  9
# sensor_04 	 NaN =  9
# sensor_05 	 NaN =  9
# sensor_06 	 NaN =  246
# sensor_07 	 NaN =  204
# sensor_08 	 NaN =  710
# sensor_09 	 NaN =  9
# sensor_10 	 NaN =  9
# sensor_11 	 NaN =  9
# sensor_12 	 NaN =  9
# sensor_13 	 NaN =  9
# sensor_14 	 NaN =  10
# sensor_15 	 NaN =  61646
# sensor_16 	 NaN =  10
# sensor_17 	 NaN =  10
# sensor_18 	 NaN =  10
# sensor_19 	 NaN =  10
# sensor_20 	 NaN =  10
# sensor_21 	 NaN =  10
# sensor_22 	 NaN =  10
# sensor_23 	 NaN =  10
# sensor_24 	 NaN =  10
# sensor_25 	 NaN =  10
# sensor_26 	 NaN =  10
# sensor_27 	 NaN =  10
# sensor_28 	 NaN =  10
# sensor_29 	 NaN =  10
# sensor_30 	 NaN =  255
# sensor_31 	 NaN =  10
# sensor_32 	 NaN =  10
# sensor_33 	 NaN =  10
# sensor_34 	 NaN =  10
# sensor_35 	 NaN =  10
# sensor_36 	 NaN =  10
# sensor_37 	 NaN =  10
# sensor_38 	 NaN =  9
# sensor_39 	 NaN =  9
# sensor_40 	 NaN =  9
# sensor_41 	 NaN =  9
# sensor_42 	 NaN =  9
# sensor_43 	 NaN =  9
# sensor_44 	 NaN =  9
# sensor_45 	 NaN =  9
# sensor_46 	 NaN =  9
# sensor_47 	 NaN =  9
# sensor_48 	 NaN =  9
# sensor_49 	 NaN =  10
# sensor_50 	 NaN =  10
# sensor_51 	 NaN =  10

# %% [markdown]
# Retirada das colunas "unnamed 0" e "sensor_15" da base junto com os dados nulos:

# %%
df = df.drop(columns=['Unnamed: 0','sensor_15'],axis=1)

df = df.dropna()

df.head()
# Out:
#         data  sensor_00  sensor_01  ...  sensor_50  sensor_51  machine_status
# 0 2018-04-01   2.465394   47.09201  ...   243.0556   201.3889          NORMAL
# 1 2018-04-01   2.465394   47.09201  ...   243.0556   201.3889          NORMAL
# 2 2018-04-01   2.444734   47.35243  ...   241.3194   203.7037          NORMAL
# 3 2018-04-01   2.460474   47.09201  ...   240.4514   203.1250          NORMAL
# 4 2018-04-01   2.445718   47.13541  ...   242.1875   201.3889          NORMAL
#
# [5 rows x 53 columns]

# %% [markdown]
# Separação da variável resposta das váriaveis independentes:

# %%
y = df['machine_status']

X = df.drop(columns=['data','machine_status'],axis=1)

# %%
y.head()
# Out:
# 0    NORMAL
# 1    NORMAL
# 2    NORMAL
# 3    NORMAL
# 4    NORMAL
# Name: machine_status, dtype: object

# %%
X.head()
# Out:
#    sensor_00  sensor_01  sensor_02  ...  sensor_49  sensor_50  sensor_51
# 0   2.465394   47.09201    53.2118  ...   67.70834   243.0556   201.3889
# 1   2.465394   47.09201    53.2118  ...   67.70834   243.0556   201.3889
# 2   2.444734   47.35243    53.2118  ...   67.12963   241.3194   203.7037
# 3   2.460474   47.09201    53.1684  ...   66.84028   240.4514   203.1250
# 4   2.445718   47.13541    53.2118  ...   66.55093   242.1875   201.3889
#
# [5 rows x 51 columns]

# %% [markdown]
# # Aplicação de StandardScaler e PCA

# %% [markdown]
# Normalização dos dados através da função Standard Scaler:

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
scaled_data = scaler.transform(X)

# %% [markdown]
# Aplicação do método PCA:

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
pca.fit(scaled_data)
# Out:
# PCA(n_components=2)

# %%
x_pca = pca.transform(scaled_data)
print(scaled_data.shape)
print(x_pca.shape)
# Out:
# (57341, 51)
# (57341, 2)

# %% [markdown]
# Avaliação dos primeiros 20 parâmetros:

# %%
nPCA = 20

pcaAll = PCA(n_components = nPCA)
pcaAll.fit(scaled_data)
x_pca_All = pcaAll.transform(scaled_data)
print(x_pca_All.shape)
print(pcaAll.explained_variance_ratio_)

pc_names= []

for i in range(nPCA):
    pc_names.append("PC%0.2d" % (i+1))
    
print(pc_names)
    
    
sns.set_theme(style="whitegrid")
plt.figure(figsize = (12,6))
ax = sns.barplot(x=pc_names, y=pcaAll.explained_variance_ratio_, color='b')
plt.tick_params(labelsize=10)
plt.xlabel('Principal Component', size = 16)
plt.ylabel('Explained Variance', size = 16)
plt.show()
# Out:
# (57341, 20)
# [0.38102778 0.14082649 0.10391849 0.05420113 0.03662046 0.03012663
#  0.02531495 0.02370028 0.01998684 0.017311   0.01608763 0.01484548
#  0.01362131 0.01227666 0.01178608 0.00963636 0.00805056 0.00759824
#  0.00722705 0.00699684]
# ['PC01', 'PC02', 'PC03', 'PC04', 'PC05', 'PC06', 'PC07', 'PC08', 'PC09', 'PC10', 'PC11', 'PC12', 'PC13', 'PC14', 'PC15', 'PC16', 'PC17', 'PC18', 'PC19', 'PC20']

# %% [markdown]
# Seleção das variáveis mais importantes:

# %%
nPCA = 8

pca10 = PCA(n_components = nPCA)
pca10.fit(scaled_data)
x_pca_aj = pca10.transform(scaled_data)
print(x_pca_aj.shape)
# Out:
# (57341, 8)

# %%
pc_names= []

for i in range(nPCA):
    pc_names.append("PC%.2d" % (i+1))
    
print(pc_names)
    
sns.set_theme(style="whitegrid")
plt.figure(figsize = (12,6))
ax = sns.barplot(x=pc_names, y=pca10.explained_variance_ratio_, color='b')
plt.tick_params(labelsize=10)
plt.xlabel('Principal Component', size = 16)
plt.ylabel('Explained Variance', size = 16)
plt.show()
# Out:
# ['PC01', 'PC02', 'PC03', 'PC04', 'PC05', 'PC06', 'PC07', 'PC08']

# %%
X_pca = pca10.transform(scaled_data)
X_pca = pd.DataFrame(X_pca, columns = pc_names)

print(X_pca.shape)

X_pca.head()
# Out:
# (57341, 8)
#        PC01      PC02      PC03  ...      PC06      PC07      PC08
# 0 -2.113977 -1.321047 -0.678069  ...  0.000334 -1.315662 -0.729263
# 1 -2.113977 -1.321047 -0.678069  ...  0.000334 -1.315662 -0.729263
# 2 -2.238225 -1.292536 -0.660798  ...  0.056511 -1.357861 -0.710729
# 3 -2.263998 -1.508815 -0.633439  ... -0.056513 -1.381917 -0.784948
# 4 -2.203656 -1.602021 -0.469888  ... -0.002044 -1.276636 -0.824185
#
# [5 rows x 8 columns]

# %% [markdown]
# # Analise com todo o data frame:

# %% [markdown]
# # Separação entre treino e teste para o modelo ( 70% dos dados para treino / 30 % para teste)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=12)

print("Tamanho do Conjunto de Treino: ",X_train.shape,"| Tamanho do Conjunto de Teste",X_test.shape)
print("Amostra da Tabela de Treino")
# Out:
# Tamanho do Conjunto de Treino:  (40138, 51) | Tamanho do Conjunto de Teste (17203, 51)
# Amostra da Tabela de Treino

# %% [markdown]
# # Implementação do modelo Naive Bayes:

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
gnb = GaussianNB()

# %%
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = gnb.predict(X_test)

# %%
print("Accuracy Naive Bayes:",metrics.accuracy_score(y_test, y_pred))
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sns.heatmap(confusion_matrix, annot=True)
# Out:
# Accuracy Naive Bayes: 0.9905249084462012

# %% [markdown]
# # Analise aplicando PCA:

# %% [markdown]
# Neste ponto com apenas as 8 variáveis mais importantes identificadas nas etapas anteriores:

# %% [markdown]
# # Separação entre treino e teste para o modelo ( 70% dos dados para treino / 30 % para teste)

# %%
from sklearn.model_selection import train_test_split

X_train_pca, X_test_pca, y_train, y_test = train_test_split(X_pca, y, test_size=0.30, random_state=12)

print("Tamanho do Conjunto de Treino: ",X_train_pca.shape,"| Tamanho do Conjunto de Teste",X_test_pca.shape)
print("Amostra da Tabela de Treino")
# Out:
# Tamanho do Conjunto de Treino:  (40138, 8) | Tamanho do Conjunto de Teste (17203, 8)
# Amostra da Tabela de Treino

# %% [markdown]
# # Implementação do modelo Naive Bayes:

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
gnb = GaussianNB()

# %%
gnb.fit(X_train_pca, y_train)
# Out:
# GaussianNB()

# %%
y_pred = gnb.predict(X_test_pca)

# %%
print("Accuracy Naive Bayes:",metrics.accuracy_score(y_test, y_pred))
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sns.heatmap(confusion_matrix, annot=True)
# Out:
# Accuracy Naive Bayes: 0.9780852176945881
